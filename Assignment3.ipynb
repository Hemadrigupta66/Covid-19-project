# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.stats as st
import seaborn as sns

# %%
file=pd.read_csv("kerala.csv")

# %%
file.head()
# Out:
#          Date Name of State  confirmed  Death  recovered  New cases
# 0  2020-01-30        Kerala          1      0          0          0
# 1  2020-01-31        Kerala          1      0          0          0
# 2  2020-02-01        Kerala          2      0          0          1
# 3  2020-02-02        Kerala          3      0          0          1
# 4  2020-02-03        Kerala          3      0          0          0

# %%
print(file.describe())
# Out:
#           confirmed       Death    recovered    New cases
# count    175.000000  175.000000   175.000000   175.000000
# mean    1958.428571    9.097143   968.748571   108.708571
# std     3718.296068   13.139689  1725.128403   263.837595
# min        1.000000    0.000000     0.000000     0.000000
# 25%       18.000000    0.000000     3.000000     0.000000
# 50%      457.000000    4.000000   338.000000     9.000000
# 75%     1959.500000   15.500000   808.500000    80.500000
# max    19025.000000   61.000000  9300.000000  2106.000000

# %%
print(file.corr())
# Out:
#            confirmed     Death  recovered  New cases
# confirmed   1.000000  0.960171   0.992465   0.883477
# Death       0.960171  1.000000   0.965828   0.827123
# recovered   0.992465  0.965828   1.000000   0.866836
# New cases   0.883477  0.827123   0.866836   1.000000

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

matplotlib.style.use('ggplot')
plt.scatter(file.recovered,file.Death)
plt.show()

# %%
plt.scatter(file.confirmed, file.recovered, )
plt.xlabel("confirmed")
plt.ylabel("cured")
plt.show()

# %%
plt.scatter(file.confirmed, file.Death, )
plt.xlabel("confirmed")
plt.ylabel("Death")
plt.show()

# %%
msk = np.random.rand(len(file)) < 0.9

train = file[msk]
test = file[~msk]

# %%
train.shape
# Out:
# (155, 6)

# %%
test.shape
# Out:
# (20, 6)

# %%
plt.scatter(train.confirmed, train.recovered,  color='blue')
plt.xlabel("trainconfiremed")
plt.ylabel("trainrecoveed")
plt.show()

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
train_x = np.asanyarray(train[['confirmed']])  #numpy.asanyarray()function is used when we want to convert input to an array
train_y = np.asanyarray(train[['recovered']])
regr.fit (train_x, train_y)
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [[0.46369591]]
# Intercept:  [64.29535927]

# %%
df=pd.read_csv("other.csv")

# %%
df.head()
# Out:
#          Date Name of State / UT  Total Confirmed cases  Death  \
# 0  2020-03-09          Karnataka                      1      0
# 1  2020-03-10          Karnataka                      4      0
# 2  2020-03-11          Karnataka                      4      0
# 3  2020-03-12     Andhra Pradesh                      1      0
# 4  2020-03-12          Karnataka                      4      1
#
#    Cured/Discharged/Migrated  New cases
# 0                          0          0
# 1                          0          3
# 2                          0          0
# 3                          0          0
# 4                          0          0

# %%
print(df.corr())
# Out:
#                            Total Confirmed cases     Death  \
# Total Confirmed cases                   1.000000  0.875744
# Death                                   0.875744  1.000000
# Cured/Discharged/Migrated               0.971730  0.893209
# New cases                               0.781527  0.610378
#
#                            Cured/Discharged/Migrated  New cases
# Total Confirmed cases                       0.971730   0.781527
# Death                                       0.893209   0.610378
# Cured/Discharged/Migrated                   1.000000   0.708096
# New cases                                   0.708096   1.000000

# %%
sns.heatmap(df.corr())
